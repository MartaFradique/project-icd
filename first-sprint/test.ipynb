# %%
import pandas as pd
import streamlit as st

# %%
data = pd.read_csv('./icd_marta_ana_scopus.csv')
data.head()
# Out:
#                                              Authors  \
# 0  Casillo M.; Conte D.; Lombardi M.; Santaniello...
# 1                          Rani C.J.; Devarakonda N.
# 2                             Lilan C.; Yongsheng C.
# 3  Min H.; Yang B.; Allen D.G.; Grandey A.A.; Liu M.
# 4  Dahroug A.; Vlachidis A.; Liapis A.; Bikakis A...
#
#                                    Author full names  \
# 0  Casillo, Mario (23026997200); Conte, Dajana (2...
# 1  Rani, Challapalli Jhansi (57870952400); Devara...
# 2  Lilan, Chen (57213686650); Yongsheng, Chen (65...
# 3  Min, Hanyi (57194326042); Yang, Baojiang (5801...
# 4  Dahroug, Ahmed (57205197369); Vlachidis, Andre...
#
#                                         Author(s) ID  \
# 0  23026997200; 22834021600; 57189595215; 5719787...
# 1                           57870952400; 54999915100
# 2                            57213686650; 6507741439
# 3  57194326042; 58019611700; 57202914326; 6603322...
# ...

# %%
chart_data = pd.DataFrame(data, columns=["Title", "Issue"])

st.line_chart(chart_data)
# Out:
# DeltaGenerator()
